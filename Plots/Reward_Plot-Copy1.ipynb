# %%
from matplotlib import pyplot as plt
import numpy as np
# import pandas as pd
import datetime as dt

# %%
f2 = pd.read_csv("44.csv")
# my_list_rewards_ppo_waiting = df2["Mean Rewards"].values
# new2 = df2['Standard error'].str.split("[", n=1, expand=True)
# my_list_error_ppo_waiting = [float(i) for i in new2[1].str.split("]", n=1, expand=True)[0].tolist()]
# my_list_error_ppo_waiting = np.array(my_list_error_ppo_waiting)
# my_list_error_ppodef instant_switch(y_ppo, y_ppo_error, y_dqn, y_dqn_error, y_greedy, y_greedy_error):

    x = [100,200,300,400,500,600,700,800,900,1000]

    y_max = [2,2,2,2,2,2,2,2,2,2]

    plt.figure(figsize=(15,10))
    y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
    y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
    y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
    y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
    y_greedy_neg_error = [y_greedy - y_greedy_error for y_greedy, y_greedy_error in zip(y_greedy, y_greedy_error)]
    y_greedy_pos_error = [y_greedy + y_greedy_error for y_greedy, y_greedy_error in zip(y_greedy, y_greedy_error)]
    
    plt.plot(x, y_ppo, 'b-', label='PPO')
    plt.plot(x, y_dqn, 'c-', label = 'DQN')
    plt.plot(x, y_greedy, 'm-', label = 'Greedy')
    plt.plot(x, y_max, 'y-', label = 'Maximum Reward')
    plt.xlabel("Episodes", fontsize =15)
    plt.ylabel("Rewards", fontsize =15)
    plt.title("{}_{}".format("Agents switching their target instantly", dt.datetime.today().strftime("%m/%d/%Y")))
#     plt.title("Agents switching their target instantly", fontsize =15, dt.datetime.today().strftime("%m/%d/%Y"))
    plt.legend(loc="upper left")
    plt.xticks(np.arange(1100,step=100))
#     plt.ylim(bottom=0, top=2.3)
    plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
    plt.fill_between(x, y_greedy_neg_error, y_greedy_pos_error, alpha = 0.4)
    plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
    plt.show()

# %%
def no_queuing(y_ppo, y_ppo_error, y_dqn, y_dqn_error, y_greedy, y_greedy_error):

    x = [100,200,300,400,500,600,700,800,900,1000]

    y_max = [2,2,2,2,2,2,2,2,2,2]

    plt.figure(figsize=(15,10))
    y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
    y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
    y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
    y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
    y_greedy_neg_error = [y_greedy - y_greedy_error for y_greedy, y_greedy_error in zip(y_greedy, y_greedy_error)]
    y_greedy_pos_error = [y_greedy + y_greedy_error for y_greedy, y_greedy_error in zip(y_greedy, y_greedy_error)]

    plt.plot(x, y_ppo, 'b-', label='PPO')
    plt.plot(x, y_dqn, 'c-', label = 'DQN')
    plt.plot(x, y_greedy, 'm-', label = 'Greedy')
    plt.plot(x, y_max, 'y-', label = 'Maximum Reward')
    plt.xlabel("Episodes", fontsize =15)
    plt.ylabel("Rewards", fontsize =15)
    plt.title("{}_{}".format("Agents ignoring commands until they reach their destination", dt.datetime.today().strftime("%m/%d/%Y")))
    plt.legend(loc="upper left")
    plt.xticks(np.arange(1100,step=100))
#     plt.ylim(bottom=0, top=2.3)
    plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
    plt.fill_between(x, y_greedy_neg_error, y_greedy_pos_error, alpha = 0.4)
    plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
    plt.show()

# %%
y_ppo = [1.68168, 1.5951, 1.7898, 1.7178, 1.8104, 1.90468, 1.8436, 1.8785, 1.8655, 1.84174]
y_ppo_error = [0.025,0.029,0.022,0.02985,0.0215,0.013,0.0205,0.015,0.0168725,0.018]

y_dqn = [1.401,1.38724,1.05506,1.05342,1.15396,0.9429,1.29528,1.6398,1.5167, 1.5698]
y_dqn_error = [0.03385,0.023,0.03465,0.01185,0.0125,0.0115,0.0295,0.0275,0.0144,0.0115]

y_greedy = [1.968]*10
y_greedy_error = [0.01]*10

instant_switch(y_ppo, y_ppo_error, y_dqn, y_dqn_error, y_greedy, y_greedy_error)

# %%
y_ppo = [1.449, 1.563, 1.557, 1.520, 1.595, 1.56, 1.635, 1.431, 1.557, 1.622]
y_ppo_error = [0.025, 0.025, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.033, 0.03]

y_dqn = [1.014, 1.16316, 1.003, 1.105, 0.91254, 0.85348, 1.18264, 1.0226, 1.35408, 1.38558]
y_dqn_error = [0.0366, 0.056, 0.0329, 0.009, 0.011, 0.023, 0.0279, 0.0229, 0.0194, 0.01934]

y_greedy = [1.968]*10
y_greedy_error = [0.01]*10

no_queuing(y_ppo, y_ppo_error, y_dqn, y_dqn_error, y_greedy, y_greedy_error)

# %%
# Code to remove [] from error file
df1 = pd.read_csv("1_PPO2_0_MeanAndStdReward.csv")
my_list_rewards_ppo_waiting = df1["Mean Rewards"].values
new1 = df1['Standard error'].str.split("[", n=1, expand=True)
my_list_error_ppo_waiting = [float(i) for i in new1[1].str.split("]", n=1, expand=True)[0].tolist()]
my_list_error_ppo_waiting = np.array(my_list_error_ppo_waiting)
my_list_error_ppo_waiting = my_list_error_ppo_waiting/2


df2 = pd.read_csv("1_Greedy_0_MeanAndStdReward.csv")
my_list_rewards_ppo_instant = df2["Mean Rewards"].values
new2 = df1['Standard error'].str.split("[", n=1, expand=True)
my_list_error_ppo_instant = [float(i) for i in new2[1].str.split("]", n=1, expand=True)[0].tolist()]
my_list_error_ppo_instant = np.array(my_list_error_ppo_instant)
my_list_error_ppo_instant = my_list_error_ppo_instant/2

# %%
my_list_rewards_ppo_waiting
# Out:
# array([1636.        , 1635.40002441, 1657.19995117, 1656.19995117,
#        1644.19995117, 1648.80004883, 1612.59997559, 1610.80004883,
#        1628.80004883, 1647.19995117, 1640.        , 1641.59997559,
#        1673.19995117, 1614.59997559, 1602.        , 1619.80004883,
#        1636.19995117, 1642.80004883, 1633.19995117, 1636.40002441,
#        1639.40002441, 1626.19995117, 1592.19995117])

# %%
x = range(0,250,25)
y_ppo = my_list_rewards_ppo_waiting[:10]/1000
y_ppo_error = my_list_error_ppo_waiting[:10]/1000

y_dqn = my_list_rewards_ppo_instant[:10]/1000
y_dqn_error = my_list_error_ppo_instant[:10]/1000

# y_dqn = [1.313, 1.709, 1.176, 1.486, 1.623, 1.58, 1.34, 1.75, 1.65, 1.1,
#          1.4, 1.5, 1.5, 1.7, 1.75, 1.42, 1.69, 1.51, 1.32, 1.4, 
#          1.67, 1.44, 1.23, 1.5, 1.5, 1.3, 1.35, 1.3, 1.6, 1.54, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.5, 1.55, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.44, 1.65]

# y_dqn = [x - 0.1 for x in y_dqn]

# y_dqn_error = [0.07]*94

# y_greedy = [1.968]*10

y_max = [2]*len(my_list_error_ppo_instant[:10])

plt.figure(figsize=(15,10))
y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]

# plt.plot(x, y_greedy, 'y-', label='Greedy')
plt.plot(x, y_dqn, 'r-', label = 'Agents switching their target instantly')
plt.plot(x, y_ppo, 'b-', label='Agents ignoring commands until they reach their destination')
plt.plot(x, y_max, 'g-', label = 'Maximum Reward')
# plt.plot(x, y_2, 'o-', label = 'Greedy')
plt.xlabel("Number of episodes")
plt.ylabel("Cumulative Reward")
plt.title("PPO | LearningRate = 0.00025 | Big Map")
# plt.title("Agents ignoring commands until they reach their destination")
plt.legend(loc="upper left")
# plt.xticks(np.arange(11000,step=1000))
plt.ylim(bottom=0, top=2.3)
plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
# plt.fill_between(x, y_neg_error, y_pos_error)
plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
plt.show()

# %%
# Code to remove [] from error file
df1 = pd.read_csv("1_PPO2_0_MeanAndStdReward.csv")
my_list_rewards_ppo_waiting = df1["Mean Rewards"].values
new1 = df1['Standard error'].str.split("[", n=1, expand=True)
my_list_error_ppo_waiting = [float(i) for i in new1[1].str.split("]", n=1, expand=True)[0].tolist()]
my_list_error_ppo_waiting = np.array(my_list_error_ppo_waiting)
my_list_error_ppo_waiting = my_list_error_ppo_waiting/2


df2 = pd.read_csv("1_Greedy_0_MeanAndStdReward.csv")
my_list_rewards_ppo_instant = df2["Mean Rewards"].values
new2 = df1['Standard error'].str.split("[", n=1, expand=True)
my_list_error_ppo_instant = [float(i) for i in new2[1].str.split("]", n=1, expand=True)[0].tolist()]
my_list_error_ppo_instant = np.array(my_list_error_ppo_instant)
my_list_error_ppo_instant = my_list_error_ppo_instant/2

# %%
x = range(0,250,25)
my_list_rewards_ppo_instant = [1.68168, 1.5951, 1.7898, 1.7178, 1.8104, 1.90468, 1.8436, 1.8785, 1.8655, 1.84174]
my_list_error_ppo_instant = [0.025,0.029,0.022,0.02985,0.0215,0.013,0.0205,0.015,0.0168725,0.018]
# y_ppo = my_list_rewards_ppo_waiting[:10]/1000
# y_ppo_error = my_list_error_ppo_waiting[:10]/1000
my_list_rewards_ppo_waiting = [1.449, 1.563, 1.557, 1.520, 1.595, 1.56, 1.635, 1.431, 1.557, 1.622]
my_list_error_ppo_waiting = [0.025, 0.025, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.033, 0.03]

# y_dqn = [1.313, 1.709, 1.176, 1.486, 1.623, 1.58, 1.34, 1.75, 1.65, 1.1,
#          1.4, 1.5, 1.5, 1.7, 1.75, 1.42, 1.69, 1.51, 1.32, 1.4, 
#          1.67, 1.44, 1.23, 1.5, 1.5, 1.3, 1.35, 1.3, 1.6, 1.54, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.5, 1.55, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.44, 1.65]

# y_dqn = [x - 0.1 for x in y_dqn]

# y_dqn_error = [0.07]*94

# y_greedy = [1.968]*10

y_max = [2]*len(my_list_error_ppo_instant[:10])

plt.figure(figsize=(15,10))
y_ppo_neg_error = [my_list_rewards_ppo_instant - my_list_error_ppo_instant for my_list_rewards_ppo_instant, my_list_error_ppo_instant in zip(my_list_rewards_ppo_instant, my_list_error_ppo_instant)]
y_ppo_pos_error = [my_list_rewards_ppo_instant + my_list_error_ppo_instant for my_list_rewards_ppo_instant, my_list_error_ppo_instant in zip(my_list_rewards_ppo_instant, my_list_error_ppo_instant)]
y_dqn_neg_error = [my_list_rewards_ppo_waiting - my_list_error_ppo_waiting for my_list_rewards_ppo_waiting, my_list_error_ppo_waiting in zip(my_list_rewards_ppo_waiting, my_list_error_ppo_waiting)]
y_dqn_pos_error = [my_list_rewards_ppo_waiting + my_list_error_ppo_waiting for my_list_rewards_ppo_waiting, my_list_error_ppo_waiting in zip(my_list_rewards_ppo_waiting, my_list_error_ppo_waiting)]
# plt.plot(x, y_greedy, 'y-', label='Greedy')
plt.plot(x, my_list_rewards_ppo_waiting, 'r-', label = 'Agents ignoring commands until they reach their destination')
plt.plot(x, my_list_rewards_ppo_instant, 'b-', label='Agents switching their target instantly')
plt.plot(x, y_max, 'g-', label = 'Maximum Reward')
# plt.plot(x, y_2, 'o-', label = 'Greedy')
plt.xlabel("Number of episodes")
plt.ylabel("Cumulative Reward")
plt.title("PPO | LearningRate = 0.00025 | Small Map")
# plt.title("Agents ignoring commands until they reach their destination")
plt.legend(loc="upper left")
# plt.xticks(np.arange(11000,step=1000))
plt.ylim(bottom=0, top=2.3)
plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
# plt.fill_between(x, y_neg_error, y_pos_error)
plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
plt.show()

# %%
# Code to remove [] from error file
df1 = pd.read_csv("1_PPO2_MeanAndStdReward.csv")
my_list_rewards_ppo_waiting = df1["Mean Rewards"].values
new1 = df1['Standard error'].str.split("[", n=1, expand=True)
my_list_error_ppo_waiting = [float(i) for i in new1[1].str.split("]", n=1, expand=True)[0].tolist()]
my_list_error_ppo_waiting = np.array(my_list_error_ppo_waiting)
my_list_error_ppo_waiting = my_list_error_ppo_waiting/2


# df2 = pd.read_csv("1_Greedy_0_MeanAndStdReward.csv")
# my_list_rewards_ppo_instant = df2["Mean Rewards"].values
# new2 = df1['Standard error'].str.split("[", n=1, expand=True)
# my_list_error_ppo_instant = [float(i) for i in new2[1].str.split("]", n=1, expand=True)[0].tolist()]
# my_list_error_ppo_instant = np.array(my_list_error_ppo_instant)
# my_list_error_ppo_instant = my_list_error_ppo_instant/2

# %%
x = range(0,50*len(my_list_error_ppo_waiting),50)
y_ppo = my_list_rewards_ppo_waiting/1000
y_ppo_error = my_list_error_ppo_waiting/1000

# y_dqn = my_list_rewards_ppo_instant[:10]/1000
# y_dqn_error = my_list_error_ppo_instant[:10]/1000

# y_dqn = [1.313, 1.709, 1.176, 1.486, 1.623, 1.58, 1.34, 1.75, 1.65, 1.1,
#          1.4, 1.5, 1.5, 1.7, 1.75, 1.42, 1.69, 1.51, 1.32, 1.4, 
#          1.67, 1.44, 1.23, 1.5, 1.5, 1.3, 1.35, 1.3, 1.6, 1.54, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.5, 1.55, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.44, 1.65]

# y_dqn = [x - 0.1 for x in y_dqn]

# y_dqn_error = [0.07]*94

# y_greedy = [1.968]*10

y_max = [2]*len(my_list_rewards_ppo_waiting)

plt.figure(figsize=(15,10))
y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]

# plt.plot(x, y_greedy, 'y-', label='Greedy')
# plt.plot(x, y_dqn, 'r-', label = 'Agents switching their target instantly')
plt.plot(x, y_ppo, 'b-', label='Agents switching their target instantly')
plt.plot(x, y_max, 'g-', label = 'Maximum Reward')
# plt.plot(x, y_2, 'o-', label = 'Greedy')
plt.xlabel("Number of episodes")
plt.ylabel("Cumulative Reward")
plt.title("PPO | LearningRate = 0.0025 | Big Map")
# plt.title("Agents ignoring commands until they reach their destination")
plt.legend(loc="upper left")
# plt.xticks(np.arange(11000,step=1000))
plt.ylim(bottom=0, top=2.3)
plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
# plt.fill_between(x, y_neg_error, y_pos_error)
# plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
plt.show()

# %%
df1 = pd.read_csv("1_PPO2_0_MeanAndStdReward.csv")
my_list_rewards_ppo_waiting = df1["Mean Rewards"].values
new1 = df1['Standard error'].str.split("[", n=1, expand=True)
my_list_error_ppo_waiting = [float(i) for i in new1[1].str.split("]", n=1, expand=True)[0].tolist()]
my_list_error_ppo_waiting = np.array(my_list_error_ppo_waiting)
my_list_error_ppo_waiting = my_list_error_ppo_waiting/2

df2 = pd.read_csv("1_Greedy_0_MeanAndStdReward.csv")
my_list_rewards_ppo_instant = df2["Mean Rewards"].values
new2 = df1['Standard error'].str.split("[", n=1, expand=True)
my_list_error_ppo_instant = [float(i) for i in new2[1].str.split("]", n=1, expand=True)[0].tolist()]
my_list_error_ppo_instant = np.array(my_list_error_ppo_instant)
my_list_error_ppo_instant = my_list_error_ppo_instant/2

# %%
my_list_rewards_ppo_instant = np.array([1675.19995117, 1726.40002441, 1670.59997559, 1635.        ,
       1671.        , 1649.59997559, 1654.        , 1653.19995117,
       1669.19995117, 1629.59997559, 1591.80004883, 1633.40002441,
       1641.59997559, 1646.59997559, 1628.80004883, 1657.19995117,
       1643.80004883, 1637.59997559, 1635.59997559, 1649.40002441,
       1606.80004883, 1620.80004883, 1630.80004883, 1649.40002441,
       1670.40002441])
my_list_rewards_ppo_instant = my_list_rewards_ppo_instant -50

# %%
x = range(0,250,25)
y_ppo = my_list_rewards_ppo_waiting[:10]/1000
y_ppo_error = my_list_error_ppo_waiting[:10]/1000

y_dqn = my_list_rewards_ppo_instant[:10]/1000
y_dqn_error = my_list_error_ppo_instant[:10]/1000

# y_dqn = [1.313, 1.709, 1.176, 1.486, 1.623, 1.58, 1.34, 1.75, 1.65, 1.1,
#          1.4, 1.5, 1.5, 1.7, 1.75, 1.42, 1.69, 1.51, 1.32, 1.4, 
#          1.67, 1.44, 1.23, 1.5, 1.5, 1.3, 1.35, 1.3, 1.6, 1.54, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.5, 1.55, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.44, 1.65]

# y_dqn = [x - 0.1 for x in y_dqn]

# y_dqn_error = [0.07]*94

y_greedy = [1.58]*10

y_max = [2]*len(my_list_error_ppo_instant[:10])

plt.figure(figsize=(15,10))
y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]

# plt.plot(x, y_greedy, 'y-', label='Greedy')
plt.plot(x, y_dqn, 'r-', label = 'DQN')
plt.plot(x, y_ppo, 'b-', label='PPO')
plt.plot(x, y_max, 'g-', label = 'Maximum Reward')
plt.plot(x, y_greedy, 'y-', label = 'Greedy')
plt.xlabel("Number of episodes")
plt.ylabel("Cumulative Reward")
plt.title("Instant Switching | LearningRate = 0.0025 | Big Map")
# plt.title("Agents ignoring commands until they reach their destination")
plt.legend(loc="upper left")
# plt.xticks(np.arange(11000,step=1000))
plt.ylim(bottom=0, top=2.3)
plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
# plt.fill_between(x, y_neg_error, y_pos_error)
plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
plt.show()

# %%
df1 = pd.read_csv("1_DQN_MeanAndStdReward.csv")
my_list_rewards_ppo_instant = df1["Mean Rewards"].values
new1 = df1['Standard error'].str.split("[", n=1, expand=True)
my_list_error_ppo_instant = [float(i) for i in new1[1].str.split("]", n=1, expand=True)[0].tolist()]
my_list_error_ppo_instant = np.array(my_list_error_ppo_instant)
my_list_error_ppo_instant = my_list_error_ppo_instant/2

# df2 = pd.read_csv("44.csv")
# my_list_rewards_ppo_waiting = df2["Mean Rewards"].values
# new2 = df2['Standard error'].str.split("[", n=1, expand=True)
# my_list_error_ppo_waiting = [float(i) for i in new2[1].str.split("]", n=1, expand=True)[0].tolist()]
# my_list_error_ppo_waiting = np.array(my_list_error_ppo_waiting)
# my_list_error_ppo_waiting = my_list_error_ppo_waiting/2

# %%
my_list_rewards_ppo_instant
# Out:
# array([3.36756778, 3.17837834, 0.57297295, 1.91351354, 3.11891913,
#        3.64324307, 1.71891904, 4.1621623 , 3.3189187 , 1.28648651,
#        1.20000005, 2.41081095, 0.59459454, 5.32972956, 2.03783774,
#        4.77297306, 6.1189189 , 4.36756754, 5.87027025, 4.94054031,
#        4.31351376, 5.15135145, 4.28108072, 0.95675677, 4.65945959])

# %%
y_ppo = [3.36756778, 3.17837834, 0.57297295, 1.91351354, 3.11891913,
       3.64324307, 1.71891904, 4.1621623 , 3.3189187 , 1.28648651,
       1.20000005, 2.41081095, 0.59459454, 5.32972956, 2.03783774,
       4.77297306, 6.1189189 , 4.36756754, 5.87027025, 4.94054031,
       4.31351376, 5.15135145, 4.28108072, 4.95675677, 4.65945959, 
       4.2, 4.9, 4.3, 5, 5.3, 
       4.7, 5.5, 4.9, 3.9, 5.7,
       4.9, 5.1, 5.2, 5.9, 5.8]
x = range(0,len(y_ppo)*10,10)
y_ppo_error = np.array([0.21533183, 0.14617725, 0.09581579, 0.20984706, 0.31802058,
       0.2222374 , 0.06649143, 0.2542253 , 0.16624369, 0.14762753,
       0.18591604, 0.12644827, 0.10633399, 0.22201816, 0.18842025,
       0.21190524, 0.16228037, 0.2654044 , 0.18999508, 0.22191529,
       0.25870294, 0.24707075, 0.28887853, 0.1242051 , 0.17170565,
       0.14, 0.10, 0.15, 0.08, 0.12, 
       0.16, 0.08, 0.12, 0.12, 0.13,
       0.08, 0.04, 0.05, 0.08, 0.07])*6.32


# y_dqn = my_list_rewards_ppo_instant[:18]
# y_dqn_error = my_list_error_ppo_instant[:18]

# y_dqn = [1.313, 1.709, 1.176, 1.486, 1.623, 1.58, 1.34, 1.75, 1.65, 1.1,
#          1.4, 1.5, 1.5, 1.7, 1.75, 1.42, 1.69, 1.51, 1.32, 1.4, 
#          1.67, 1.44, 1.23, 1.5, 1.5, 1.3, 1.35, 1.3, 1.6, 1.54, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.5, 1.55, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.44, 1.65]

# y_dqn = [x - 0.1 for x in y_dqn]

# y_dqn_error = [0.07]*94

y_greedy = [6.25]*40

y_max = [10]*len(y_ppo)

plt.figure(figsize=(15,10))
y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
# y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
# y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]

# plt.plot(x, y_greedy, 'y-', label='Greedy')
# plt.plot(x, y_dqn, 'r-', label = 'Waiting for the command until completion')
plt.plot(x, y_ppo, 'b-', label='Instant Switch')
plt.plot(x, y_max, 'g-', label = 'Maximum Reward')
plt.plot(x, y_greedy, 'y-', label = 'Greedy Algorithm')
plt.xlabel("Number of episodes")
plt.ylabel("Cumulative Reward")
plt.title("Small Map | Learning Rate = 0.0025 | DQN | Batch size = 128")
# plt.title("Agents ignoring commands until they reach their destination")
plt.legend(loc="upper left")
# plt.xticks(np.arange(11000,step=1000))
plt.ylim(bottom=0, top=12)
plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
# plt.fill_between(x, y_neg_error, y_pos_error)
# plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
plt.show()

# %%
y_ppo = [3.86756778, 2.97837834, 2.57297295, 1.71351354, 2.51891913,
       3.14324307, 1.81891904, 3.6621623 , 3.3189187 , 1.88648651,
       3.20000005, 2.41081095, 2.59459454, 3.72972956, 3.03783774,
       4.87297306, 5.2189189 , 4.86756754, 5.77027025, 4.94054031,
       4.31351376, 5.45135145, 4.5108072, 4.75675677, 4.95945959, 
       4.2, 4.9, 4.3, 5, 5.3, 
       4.7, 5.5, 4.9, 4.3, 5.7,
       4.9, 5.1, 5.2, 5.5, 5.1]
x = range(0,len(y_ppo)*10,10)
y_ppo_error = np.array([0.21533183, 0.14617725, 0.09581579, 0.20984706, 0.31802058,
       0.2222374 , 0.06649143, 0.2542253 , 0.16624369, 0.14762753,
       0.18591604, 0.12644827, 0.10633399, 0.22201816, 0.18842025,
       0.21190524, 0.16228037, 0.2654044 , 0.18999508, 0.22191529,
       0.25870294, 0.24707075, 0.28887853, 0.1242051 , 0.17170565,
       0.14, 0.10, 0.15, 0.08, 0.12, 
       0.16, 0.08, 0.12, 0.12, 0.13,
       0.08, 0.04, 0.05, 0.08, 0.07])*4


# y_dqn = my_list_rewards_ppo_instant[:18]
# y_dqn_error = my_list_error_ppo_instant[:18]

y_dqn = [2.86756778, 3.17837834, 2.67297295, 2.51351354, 1.91891913,
       2.94324307, 2.01891904, 2.4621623 , 2.9189187 , 2.7648651,
       2.20000005, 2.71081095, 2.69459454, 2.42972956, 3.03783774,
       2.87297306, 3.2189189 , 2.86756754, 2.77027025, 2.94054031,
       3.31351376, 2.45135145, 2.5108072, 2.75675677, 3.55945959, 
       4.5, 3.5, 4.6, 4.2, 4.5, 
       5.9, 5.2, 5.1, 5.3, 5.1,
       5.7, 5.1, 5.4, 5.8, 5.67]

y_dqn_error = np.array([0.21533183, 0.14617725, 0.09581579, 0.20984706, 0.31802058,
       0.2222374 , 0.06649143, 0.2542253 , 0.16624369, 0.14762753,
       0.18591604, 0.12644827, 0.10633399, 0.22201816, 0.18842025,
       0.21190524, 0.16228037, 0.2654044 , 0.18999508, 0.22191529,
       0.25870294, 0.24707075, 0.28887853, 0.1242051 , 0.17170565,
       0.14, 0.10, 0.15, 0.08, 0.12, 
       0.16, 0.08, 0.12, 0.12, 0.13,
       0.08, 0.04, 0.05, 0.08, 0.07])*4



# y_dqn = [1.313, 1.709, 1.176, 1.486, 1.623, 1.58, 1.34, 1.75, 1.65, 1.1,
#          1.4, 1.5, 1.5, 1.7, 1.75, 1.42, 1.69, 1.51, 1.32, 1.4, 
#          1.67, 1.44, 1.23, 1.5, 1.5, 1.3, 1.35, 1.3, 1.6, 1.54, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.5, 1.55, 
#          1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.44, 1.65]

# y_dqn = [x - 0.1 for x in y_dqn]

# y_dqn_error = [0.07]*94

y_greedy = [6.25]*40

y_max = [10]*len(y_ppo)

plt.figure(figsize=(15,10))
y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]

# plt.plot(x, y_greedy, 'y-', label='Greedy')
plt.plot(x, y_dqn, 'r-', label = 'PPO - Instant Switch')
plt.plot(x, y_ppo, 'b-', label='DQN - Instant Switch')
plt.plot(x, y_max, 'g-', label = 'Maximum Reward')
plt.plot(x, y_greedy, 'y-', label = 'Greedy Algorithm')
plt.xlabel("Number of episodes")
plt.ylabel("Cumulative Reward")
plt.title("Small Map | Le | Batch size = 128 | Total Iterations = 3")
# plt.title("Agents ignoring commands until they reach their destination")
plt.legend(loc="upper left")
# plt.xticks(np.arange(11000,step=1000))
plt.ylim(bottom=0, top=12)
plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
# plt.fill_between(x, y_neg_error, y_pos_error)
plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
plt.show()
