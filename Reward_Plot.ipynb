# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt

# %%
def instant_switch(y_ppo, y_ppo_error, y_dqn, y_dqn_error, y_greedy, y_greedy_error):

    x = [100,200,300,400,500,600,700,800,900,1000]

    y_max = [2,2,2,2,2,2,2,2,2,2]

    plt.figure(figsize=(15,10))
    y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
    y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
    y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
    y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
    y_greedy_neg_error = [y_greedy - y_greedy_error for y_greedy, y_greedy_error in zip(y_greedy, y_greedy_error)]
    y_greedy_pos_error = [y_greedy + y_greedy_error for y_greedy, y_greedy_error in zip(y_greedy, y_greedy_error)]
    
    plt.plot(x, y_ppo, 'b-', label='PPO')
    plt.plot(x, y_dqn, 'c-', label = 'DQN')
    plt.plot(x, y_greedy, 'm-', label = 'Greedy')
    plt.plot(x, y_max, 'y-', label = 'Maximum Reward')
    plt.xlabel("Episodes", fontsize =15)
    plt.ylabel("Rewards", fontsize =15)
    plt.title("{}_{}".format("Agents switching their target instantly", dt.datetime.today().strftime("%m/%d/%Y")))
#     plt.title("Agents switching their target instantly", fontsize =15, dt.datetime.today().strftime("%m/%d/%Y"))
    plt.legend(loc="upper left")
    plt.xticks(np.arange(1100,step=100))
    plt.ylim(bottom=0, top=2.3)
    plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
    plt.fill_between(x, y_greedy_neg_error, y_greedy_pos_error, alpha = 0.4)
    plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
    plt.show()

# %%
def no_queuing(y_ppo, y_ppo_error, y_dqn, y_dqn_error, y_greedy, y_greedy_error):

    x = [100,200,300,400,500,600,700,800,900,1000]

    y_max = [2,2,2,2,2,2,2,2,2,2]

    plt.figure(figsize=(15,10))
    y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
    y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
    y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
    y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
    y_greedy_neg_error = [y_greedy - y_greedy_error for y_greedy, y_greedy_error in zip(y_greedy, y_greedy_error)]
    y_greedy_pos_error = [y_greedy + y_greedy_error for y_greedy, y_greedy_error in zip(y_greedy, y_greedy_error)]

    plt.plot(x, y_ppo, 'b-', label='PPO')
    plt.plot(x, y_dqn, 'c-', label = 'DQN')
    plt.plot(x, y_greedy, 'm-', label = 'Greedy')
    plt.plot(x, y_max, 'y-', label = 'Maximum Reward')
    plt.xlabel("Episodes", fontsize =15)
    plt.ylabel("Rewards", fontsize =15)
    plt.title("{}_{}".format("Agents ignoring commands until they reach their destination", dt.datetime.today().strftime("%m/%d/%Y")))
    plt.legend(loc="upper left")
    plt.xticks(np.arange(1100,step=100))
    plt.ylim(bottom=0, top=2.3)
    plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
    plt.fill_between(x, y_greedy_neg_error, y_greedy_pos_error, alpha = 0.4)
    plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
    plt.show()

# %%
y_ppo = [1.68168, 1.5951, 1.7898, 1.7178, 1.8104, 1.90468, 1.8436, 1.8785, 1.8655, 1.84174]
y_ppo_error = [0.025,0.029,0.022,0.02985,0.0215,0.013,0.0205,0.015,0.0168725,0.018]

y_dqn = [1.401,1.38724,1.05506,1.05342,1.15396,0.9429,1.29528,1.6398,1.5167, 1.5698]
y_dqn_error = [0.03385,0.023,0.03465,0.01185,0.0125,0.0115,0.0295,0.0275,0.0144,0.0115]

y_greedy = [1.968]*10
y_greedy_error = [0.01]*10

instant_switch(y_ppo, y_ppo_error, y_dqn, y_dqn_error, y_greedy, y_greedy_error)

# %%
y_ppo = [1.449, 1.563, 1.557, 1.520, 1.595, 1.56, 1.635, 1.431, 1.557, 1.622]
y_ppo_error = [0.025, 0.025, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.033, 0.03]

y_dqn = [1.014, 1.16316, 1.003, 1.105, 0.91254, 0.85348, 1.18264, 1.0226, 1.35408, 1.38558]
y_dqn_error = [0.0366, 0.056, 0.0329, 0.009, 0.011, 0.023, 0.0279, 0.0229, 0.0194, 0.01934]

y_greedy = [1.968]*10
y_greedy_error = [0.01]*10

no_queuing(y_ppo, y_ppo_error, y_dqn, y_dqn_error, y_greedy, y_greedy_error)

# %%
# Code to remove [] from error file
df1 = pd.read_csv("1_Greedy_MeanAndStdReward.csv")
my_list_rewards_ppo = df1["Mean Rewards"].values
new = df1['Standard error'].str.split("[", n=1, expand=True)
my_list_error_ppo = [float(i) for i in new[1].str.split("]", n=1, expand=True)[0].tolist()]
my_list_error_ppo = np.array(my_list_error_ppo)
my_list_error_ppo = my_list_error_ppo/2

# %%
x = range(0,250,5)
y_ppo = my_list_rewards_ppo
y_ppo_error = my_list_error_ppo

y_dqn = [1.313, 1.709, 1.176, 1.486, 1.623, 1.58, 1.34, 1.75, 1.65, 1.1,
         1.4, 1.5, 1.5, 1.7, 1.75, 1.42, 1.69, 1.51, 1.32, 1.4, 
         1.67, 1.44, 1.23, 1.5, 1.5, 1.3, 1.35, 1.3, 1.6, 1.54, 
         1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.5, 1.55, 
         1.66, 1.6, 1.4, 1.3, 1.45, 1.25, 1.6, 1.7, 1.44, 1.65]

y_dqn = [x - 0.1 for x in y_dqn]

y_dqn_error = [0.07]*50

y_greedy = [1.968]*50

y_max = [2]*50

plt.figure(figsize=(15,10))
y_ppo_neg_error = [y_ppo - y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_ppo_pos_error = [y_ppo + y_ppo_error for y_ppo, y_ppo_error in zip(y_ppo, y_ppo_error)]
y_dqn_neg_error = [y_dqn - y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
y_dqn_pos_error = [y_dqn + y_dqn_error for y_dqn, y_dqn_error in zip(y_dqn, y_dqn_error)]
plt.plot(x, y_ppo, 'b-', label='PPO')
plt.plot(x, y_greedy, 'y-', label='Greedy')
plt.plot(x, y_dqn, 'r-', label = 'DQN')
plt.plot(x, y_max, 'g-', label = 'Maximum Reward')
# plt.plot(x, y_2, 'o-', label = 'Greedy')
plt.xlabel("Number of episodes")
plt.ylabel("Cumulative Reward")
plt.title("Agents ignoring commands until they reach their destination")
plt.legend(loc="upper left")
# plt.xticks(np.arange(11000,step=1000))
plt.ylim(bottom=0, top=2.3)
plt.fill_between(x, y_ppo_neg_error, y_ppo_pos_error , alpha=0.4)
# plt.fill_between(x, y_neg_error, y_pos_error)
plt.fill_between(x, y_dqn_neg_error, y_dqn_pos_error, alpha=0.4)
plt.show()
